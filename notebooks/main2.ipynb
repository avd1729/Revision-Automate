# %%
import numpy as np
import pandas as pd

# %%
import json

file_path = "C:/Users/Aravind/PROJECTS/notion-dsa-reminder-workflow/out/response_output.json"

with open(file_path, 'r') as file:
    data = json.load(file)

print(type(data)) 
print(data)

# # Check if data is a list or a dictionary
# if isinstance(data, dict):
#     # If it's a single dictionary, wrap it in a list
#     data = [data]

# Convert to DataFrame
df = pd.DataFrame(data)

print(df.head())
# Out:
# <class 'list'>
# [{'object': 'page', 'id': '1a2555a6-5088-40a8-9e0f-17fc5c8d9dd4', 'created_time': '2024-08-05T09:52:00.000Z', 'last_edited_time': '2024-08-06T07:36:00.000Z', 'created_by': {'object': 'user', 'id': '630b6e08-af06-4508-b35e-e9effda7d8e9'}, 'last_edited_by': {'object': 'user', 'id': '630b6e08-af06-4508-b35e-e9effda7d8e9'}, 'cover': {'type': 'external', 'external': {'url': 'https://www.notion.so/images/page-cover/webb3.jpg'}}, 'icon': {'type': 'emoji', 'emoji': '⚓'}, 'parent': {'type': 'database_id', 'database_id': 'ad1cbfab-99d3-49ed-af27-4454906f89fc'}, 'archived': False, 'in_trash': False, 'properties': {'Topic': {'id': '%3E%5Eur', 'type': 'multi_select', 'multi_select': [{'id': 'fb51ca1b-a755-4220-9920-e5503add33f1', 'name': 'Recursion', 'color': 'blue'}, {'id': 'bcb1129b-c849-4b70-8292-ac993fdb8fe8', 'name': 'Backtracking', 'color': 'pink'}, {'id': '894607b3-7db4-4d3f-a00a-f296cd58b273', 'name': 'BFS', 'color': 'green'}, {'id': '616c2edc-54a4-4664-a84c-79483348a2fe', 'name': 'Queue', 'color': 'green'}]}, 'Date': {'id': 'BS%3CH', 'type': 'date', 'date': {'start': '2024-08-06', 'end': None, 'time_zone': None}}, 'Assignee': {'id': 'E%40%7Di', 'type': 'people', 'people': []}, 'Optimization': {'id': 'Evs%7D', 'type': 'select', 'select': {'id': 'b7b42918-15db-42f5-a61b-b29833ef5251', 'name': 'Best', 'color': 'green'}}, 'Action': {'id': 'c%3Ci%5C', 'type': 'status', 'status': {'id': '60203c43-c2c4-41e7-877c-373166979890', 'name': 'Revisit', 'color': 'blue'}}, 'Difficulty': {'id': '%7BMsS', 'type': 'select', 'select': {'id': 'XEU{', 'name': 'Medium', 'color': 'yellow'}}, 'Problem': {'id': 'title', 'type': 'title', 'title': [{'type': 'text', 'text': {'content': 'Find shortest safe route in a path with landmines', 'link': None}, 'annotations': {'bold': True, 'italic': False, 'strikethrough': False, 'underline': False, 'code': False, 'color': 'default'}, 'plain_text': 'Find shortest safe route in a path with landmines', 'href': None}]}}, 'url': 'https://www.notion.so/Find-shortest-safe-route-in-a-path-with-landmines-1a2555a6508840a89e0f17fc5c8d9dd4', 'public_url': None}, {'object': 'page', 'id': '18f47068-4acd-46fd-a9f5-0e5afd1ea9b2', 'created_time': '2024-08-05T09:04:00.000Z', 'last_edited_time': '2024-08-05T09:11:00.000Z', 'created_by': {'object': 'user', 'id': '630b6e08-af06-4508-b35e-e9effda7d8e9'}, 'last_edited_by': {'object': 'user', 'id': '630b6e08-af06-4508-b35e-e9effda7d8e9'}, 'cover': {'type': 'external', 'external': {'url': 'https://www.notion.so/images/page-cover/met_william_morris_1878.jpg'}}, 'icon': {'type': 'emoji', 'emoji': '⚓'}, 'parent': {'type': 'database_id', 'database_id': 'ad1cbfab-99d3-49ed-af27-4454906f89fc'}, 'archived': False, 'in_trash': False, 'properties': {'Topic': {'id': '%3E%5Eur', 'type': 'multi_select', 'multi_select': [{'id': 'fb51ca1b-a755-4220-9920-e5503add33f1', 'name': 'Recursion', 'color': 'blue'}, {'id': 'bcb1129b-c849-4b70-8292-ac993fdb8fe8', 'name': 'Backtracking', 'color': 'pink'}]}, 'Date': {'id': 'BS%3CH', 'type': 'date', 'date': {'start': '2024-08-03', 'end': None, 'time_zone': None}}, 'Assignee': {'id': 'E%40%7Di', 'type': 'people', 'people': []}, 'Optimization': {'id': 'Evs%7D', 'type': 'select', 'select': {'id': 'b7b42918-15db-42f5-a61b-b29833ef5251', 'name': 'Best', 'color': 'green'}}, 'Action': {'id': 'c%3Ci%5C', 'type': 'status', 'status': {'id': '300dae81-8976-485c-b3b2-d0c2a19b1489', 'name': 'Done', 'color': 'green'}}, 'Difficulty': {'id': '%7BMsS', 'type': 'select', 'select': {'id': '<O}^', 'name': 'Easy', 'color': 'green'}}, 'Problem': {'id': 'title', 'type': 'title', 'title': [{'type': 'text', 'text': {'content': 'Subset sum (Strings)', 'link': None}, 'annotations': {'bold': False, 'italic': False, 'strikethrough': False, 'underline': False, 'code': False, 'color': 'default'}, 'plain_text': 'Subset sum (Strings)', 'href': None}]}}, 'url': 'https://www.notion.so/Subset-sum-Strings-18f470684acd46fda9f50e5afd1ea9b2', 'public_url': None}, {'object': 'page', 'id': 'c8d99b2d-768f-45ca ...
#   object                                    id              created_time  \
# 0   page  1a2555a6-5088-40a8-9e0f-17fc5c8d9dd4  2024-08-05T09:52:00.000Z
# 1   page  18f47068-4acd-46fd-a9f5-0e5afd1ea9b2  2024-08-05T09:04:00.000Z
# 2   page  c8d99b2d-768f-45ca-a92e-63771bf2c93c  2024-08-01T11:52:00.000Z
# 3   page  f09893ad-6e10-48cd-bb27-25f6d6d8646f  2024-08-05T09:03:00.000Z
# 4   page  252d90a3-a1b5-49b2-93b5-bb9214448800  2024-08-05T09:00:00.000Z
#
#            last_edited_time  \
# 0  2024-08-06T07:36:00.000Z
# 1  2024-08-05T09:11:00.000Z
# 2  2024-08-05T09:08:00.000Z
# 3  2024-08-05T09:04:00.000Z
# 4  2024-08-05T09:01:00.000Z
#
#                                           created_by  \
# 0  {'object': 'user', 'id': '630b6e08-af06-4508-b...
# 1  {'object': 'user', 'id': '630b6e08-af06-4508-b...
# 2  {'object': 'user', 'id': '630b6e08-af06-4508-b...
# 3  {'object': 'user', 'id': '630b6e08-af06-4508-b...
# 4  {'object': 'user', 'id': '630b6e08-af06-4508-b...
#
#                                       last_edited_by  \
# 0  {'object': 'user', 'id': '630b6e08-af06-4508-b...
# 1  {'object': 'user', 'id': '630b6e08-af06-4508-b...
# 2  {'object': 'user', 'id': '630b6e08-af06-4508-b...
# 3  {'object': 'user', 'id': '630b6e08-af06-4508-b...
# 4  {'object': 'user', 'id': '630b6e08-af06-4508-b...
#
#                                                cover  \
# 0  {'type': 'external', 'external': {'url': 'http...
# 1  {'type': 'external', 'external': {'url': 'http...
# 2  {'type': 'external', 'external': {'url': 'http...
# 3  {'type': 'external', 'external': {'url': 'http...
# 4  {'type': 'external', 'external': {'url': 'http...
#
#                               icon  \
# 0  {'type': 'emoji', 'emoji': '⚓'}
# 1  {'type': 'emoji', 'emoji': '⚓'}
# 2  {'type': 'emoji', 'emoji': '⚓'}
# 3  {'type': 'emoji', 'emoji': '⚓'}
# 4  {'type': 'emoji', 'emoji': '⚓'}
#
#                                               parent  archived  in_trash  \
# 0  {'type': 'database_id', 'database_id': 'ad1cbf...     False     False
# 1  {'type': 'database_id', 'database_id': 'ad1cbf...     False     False
# 2  {'type': 'database_id', 'database_id': 'ad1cbf...     False     False
# 3  {'type': 'database_id', 'database_id': 'ad1cbf...     False     False
# 4  {'type': 'database_id', 'database_id': 'ad1cbf...     False     False
#
#                                           properties  \
# 0  {'Topic': {'id': '%3E%5Eur', 'type': 'multi_se...
# 1  {'Topic': {'id': '%3E%5Eur', 'type': 'multi_se...
# 2  {'Topic': {'id': '%3E%5Eur', 'type': 'multi_se...
# 3  {'Topic': {'id': '%3E%5Eur', 'type': 'multi_se...
# 4  {'Topic': {'id': '%3E%5Eur', 'type': 'multi_se...
#
#                                                  url public_url
# 0  https://www.notion.so/Find-shortest-safe-route...       None
# 1  https://www.notion.so/Subset-sum-Strings-18f47...       None
# 2  https://www.notion.so/Find-paths-from-corner-c...       None
# 3  https://www.notion.so/Longest-Possible-Route-i...       None
# 4  https://www.notion.so/Tug-of-War-252d90a3a1b54...       None

# %%
print(df.head())
# Out:
#   object                                    id              created_time  \
# 0   page  1a2555a6-5088-40a8-9e0f-17fc5c8d9dd4  2024-08-05T09:52:00.000Z
# 1   page  18f47068-4acd-46fd-a9f5-0e5afd1ea9b2  2024-08-05T09:04:00.000Z
# 2   page  c8d99b2d-768f-45ca-a92e-63771bf2c93c  2024-08-01T11:52:00.000Z
# 3   page  f09893ad-6e10-48cd-bb27-25f6d6d8646f  2024-08-05T09:03:00.000Z
# 4   page  252d90a3-a1b5-49b2-93b5-bb9214448800  2024-08-05T09:00:00.000Z
#
#            last_edited_time  \
# 0  2024-08-06T07:36:00.000Z
# 1  2024-08-05T09:11:00.000Z
# 2  2024-08-05T09:08:00.000Z
# 3  2024-08-05T09:04:00.000Z
# 4  2024-08-05T09:01:00.000Z
#
#                                           created_by  \
# 0  {'object': 'user', 'id': '630b6e08-af06-4508-b...
# 1  {'object': 'user', 'id': '630b6e08-af06-4508-b...
# 2  {'object': 'user', 'id': '630b6e08-af06-4508-b...
# 3  {'object': 'user', 'id': '630b6e08-af06-4508-b...
# 4  {'object': 'user', 'id': '630b6e08-af06-4508-b...
#
#                                       last_edited_by  \
# 0  {'object': 'user', 'id': '630b6e08-af06-4508-b...
# 1  {'object': 'user', 'id': '630b6e08-af06-4508-b...
# 2  {'object': 'user', 'id': '630b6e08-af06-4508-b...
# 3  {'object': 'user', 'id': '630b6e08-af06-4508-b...
# 4  {'object': 'user', 'id': '630b6e08-af06-4508-b...
#
#                                                cover  \
# 0  {'type': 'external', 'external': {'url': 'http...
# 1  {'type': 'external', 'external': {'url': 'http...
# 2  {'type': 'external', 'external': {'url': 'http...
# 3  {'type': 'external', 'external': {'url': 'http...
# 4  {'type': 'external', 'external': {'url': 'http...
#
#                               icon  \
# 0  {'type': 'emoji', 'emoji': '⚓'}
# 1  {'type': 'emoji', 'emoji': '⚓'}
# 2  {'type': 'emoji', 'emoji': '⚓'}
# 3  {'type': 'emoji', 'emoji': '⚓'}
# 4  {'type': 'emoji', 'emoji': '⚓'}
#
#                                               parent  archived  in_trash  \
# 0  {'type': 'database_id', 'database_id': 'ad1cbf...     False     False
# 1  {'type': 'database_id', 'database_id': 'ad1cbf...     False     False
# 2  {'type': 'database_id', 'database_id': 'ad1cbf...     False     False
# 3  {'type': 'database_id', 'database_id': 'ad1cbf...     False     False
# 4  {'type': 'database_id', 'database_id': 'ad1cbf...     False     False
#
#                                           properties  \
# 0  {'Topic': {'id': '%3E%5Eur', 'type': 'multi_se...
# 1  {'Topic': {'id': '%3E%5Eur', 'type': 'multi_se...
# 2  {'Topic': {'id': '%3E%5Eur', 'type': 'multi_se...
# 3  {'Topic': {'id': '%3E%5Eur', 'type': 'multi_se...
# 4  {'Topic': {'id': '%3E%5Eur', 'type': 'multi_se...
#
#                                                  url public_url
# 0  https://www.notion.so/Find-shortest-safe-route...       None
# 1  https://www.notion.so/Subset-sum-Strings-18f47...       None
# 2  https://www.notion.so/Find-paths-from-corner-c...       None
# 3  https://www.notion.so/Longest-Possible-Route-i...       None
# 4  https://www.notion.so/Tug-of-War-252d90a3a1b54...       None

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170 entries, 0 to 169
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   object            170 non-null    object
#  1   id                170 non-null    object
#  2   created_time      170 non-null    object
#  3   last_edited_time  170 non-null    object
#  4   created_by        170 non-null    object
#  5   last_edited_by    170 non-null    object
#  6   cover             162 non-null    object
#  7   icon              169 non-null    object
#  8   parent            170 non-null    object
#  9   archived          170 non-null    bool
#  10  in_trash          170 non-null    bool
#  11  properties        170 non-null    object
#  12  url               170 non-null    object
#  13  public_url        0 non-null      object
# dtypes: bool(2), object(12)
# memory usage: 16.4+ KB
# None

# %%
new_df = pd.DataFrame({
    "Date": df["properties"].apply(lambda x: x["Date"]["date"]["start"] if x["Date"] and x["Date"]["date"] else None),
    "Problem Title": df["properties"].apply(lambda x: x["Problem"]["title"][0]["text"]["content"] if x["Problem"] and x["Problem"]["title"] else None),
    "URL":df['url']
})

# %%
print(new_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170 entries, 0 to 169
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           169 non-null    object
#  1   Problem Title  169 non-null    object
#  2   URL            170 non-null    object
# dtypes: object(3)
# memory usage: 4.1+ KB
# None

# %%
print(new_df.head())
# Out:
#          Date                                      Problem Title  \
# 0  2024-08-06  Find shortest safe route in a path with landmines
# 1  2024-08-03                               Subset sum (Strings)
# 2  2024-08-01  Find paths from corner cell to middle cell in ...
# 3  2024-08-03    Longest Possible Route in a Matrix with Hurdles
# 4  2024-08-03                                         Tug of War
#
#                                                  URL
# 0  https://www.notion.so/Find-shortest-safe-route...
# 1  https://www.notion.so/Subset-sum-Strings-18f47...
# 2  https://www.notion.so/Find-paths-from-corner-c...
# 3  https://www.notion.so/Longest-Possible-Route-i...
# 4  https://www.notion.so/Tug-of-War-252d90a3a1b54...

# %%
new_df['Date'] = pd.to_datetime(new_df['Date'])

# Sorting the dataframe by 'Date'
sorted_df = new_df.sort_values(by='Date')

# Printing sorted dataframe
print(sorted_df)
# Out:
#           Date                                      Problem Title  \
# 114 2024-03-03                        Check if an Array is Sorted
# 142 2024-03-03  Find Second Smallest and Second Largest Elemen...
# 143 2024-03-03               Find the Largest element in an array
# 144 2024-03-04                         Rotate array by K elements
# 109 2024-03-05                         Union of Two Sorted Arrays
# ..         ...                                                ...
# 4   2024-08-03                                         Tug of War
# 3   2024-08-03    Longest Possible Route in a Matrix with Hurdles
# 1   2024-08-03                               Subset sum (Strings)
# 0   2024-08-06  Find shortest safe route in a path with landmines
# 164        NaT                                               None
#
#                                                    URL
# 114  https://www.notion.so/Check-if-an-Array-is-Sor...
# 142  https://www.notion.so/Find-Second-Smallest-and...
# 143  https://www.notion.so/Find-the-Largest-element...
# 144  https://www.notion.so/Rotate-array-by-K-elemen...
# 109  https://www.notion.so/Union-of-Two-Sorted-Arra...
# ..                                                 ...
# 4    https://www.notion.so/Tug-of-War-252d90a3a1b54...
# 3    https://www.notion.so/Longest-Possible-Route-i...
# 1    https://www.notion.so/Subset-sum-Strings-18f47...
# 0    https://www.notion.so/Find-shortest-safe-route...
# 164  https://www.notion.so/3572678c96f745548770fdab...
#
# [170 rows x 3 columns]

# %%
import datetime

# Function to create a subset of the DataFrame
def create_date_subsets(df):
    # Getting the current date
    current_date = pd.to_datetime('2024-05-10')
    
    # Creating time intervals
    two_days_before = current_date - pd.Timedelta(days=2)
    seven_days_before = current_date - pd.Timedelta(days=7)
    fourteen_days_before = current_date - pd.Timedelta(days=14)
    thirty_days_before = current_date - pd.Timedelta(days=30)
    
    # Filtering the dataframe based on the date ranges
    df_filtered = df[
        (df['Date'] == two_days_before) |
        (df['Date'] == seven_days_before) |
        (df['Date'] == fourteen_days_before) |
        (df['Date'] == thirty_days_before)
    ]
    
    return df_filtered

filtered_df = create_date_subsets(sorted_df)

# %%
print(filtered_df)
# Out:
#          Date                                      Problem Title  \
# 93 2024-04-10                                      Rotate String
# 91 2024-04-10                       Sort Characters By Frequency
# 92 2024-04-10                                      Valid Anagram
# 72 2024-04-26  Delete all occurrences of a given key in a dou...
# 56 2024-05-03         Pairwise Swap Nodes of a given Linked List
# 55 2024-05-03  Write a function that counts the number of tim...
# 54 2024-05-03                       Sort linked list of 0s 1s 2s
# 53 2024-05-03  Convert singly linked list into circular linke...
# 32 2024-05-08    Find pairs with given sum in doubly linked list
# 33 2024-05-08  Remove duplicates from an unsorted doubly link...
#
#                                                   URL
# 93  https://www.notion.so/Rotate-String-2717a676f0...
# 91  https://www.notion.so/Sort-Characters-By-Frequ...
# 92  https://www.notion.so/Valid-Anagram-fe263223ad...
# 72  https://www.notion.so/Delete-all-occurrences-o...
# 56  https://www.notion.so/Pairwise-Swap-Nodes-of-a...
# 55  https://www.notion.so/Write-a-function-that-co...
# 54  https://www.notion.so/Sort-linked-list-of-0s-1...
# 53  https://www.notion.so/Convert-singly-linked-li...
# 32  https://www.notion.so/Find-pairs-with-given-su...
# 33  https://www.notion.so/Remove-duplicates-from-a...

# %%
from dotenv import load_dotenv
import os

load_dotenv()
EMAIL_ID = os.getenv("EMAIL_ID")
PASS_WD = os.getenv("PASS_WD")

# %%
import datetime

# Function to format the DataFrame data into a readable email format
def format_dataframe(df):
    email_body = ""
    for idx, row in df.iterrows():
        email_body += f"Question {idx + 1}:\n"
        email_body += f"Date: {row['Date'].strftime('%Y-%m-%d')}\n"
        email_body += f"Problem Title: {row['Problem Title']}\n"
        email_body += f"URL: {row['URL']}\n"  # You can replace with actual URLs if available
        email_body += "\n"  # Line break between questions
    return email_body

# %%
# Get the current date for the email subject
current_date = datetime.datetime.now().strftime('%Y-%m-%d')
subject = f"DSA Reminder - {current_date}"

# %%
import pytz
from googleapiclient.discovery import build
def add_event_to_calendar(creds, title, url):
    service = build('calendar', 'v3', credentials=creds)
    
    utc_now = datetime.datetime.now(pytz.utc)  # Get the current UTC time
    current_date = utc_now.date()
    event_date = current_date.strftime('%Y-%m-%d')

    # Create the event with title and description including the URL
    event = {
        'summary': title,
        'description': f'Problem URL: {url}',  # Include URL in the description
        'start': {
            'date': event_date,  # All-day event using current date
            'timeZone': 'UTC',   # Adjust timezone as needed
        },
        'end': {
            'date': event_date,  # All-day event using current date
            'timeZone': 'UTC',
        },
    }
    
    # Insert the event into the user's calendar
    event = service.events().insert(calendarId='primary', body=event).execute()
    print(f"Event created: {event.get('htmlLink')}")

# %%
import os
import base64
import google.auth
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
from googleapiclient.discovery import build
from email.mime.text import MIMEText

# Define the scope for Gmail API
SCOPES = [
    'https://www.googleapis.com/auth/gmail.send',
    'https://www.googleapis.com/auth/calendar',
    'https://www.googleapis.com/auth/calendar.events'
]


# Path to credentials.json from the Google Cloud Console
CREDENTIALS_FILE = 'C:/Users/Aravind/PROJECTS/notion-dsa-reminder-workflow/secrets/credentials.json'

# Function to authenticate and get the credentials
def authenticate():
    creds = None
    token_file = 'C:/Users/Aravind/PROJECTS/notion-dsa-reminder-workflow/secrets/token.json'

    # Load previously stored credentials if they exist
    if os.path.exists(token_file):
        creds = Credentials.from_authorized_user_file(token_file, SCOPES)

    # If no valid credentials are available, ask the user to log in
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(CREDENTIALS_FILE, SCOPES)
            creds = flow.run_local_server(port=0)

        # Save the credentials for future use
        with open(token_file, 'w') as token:
            token.write(creds.to_json())

    return creds

# Function to send an email
def send_email(creds, sender_email, recipient_email, subject, body):
    service = build('gmail', 'v1', credentials=creds)

    # Create the email message
    message = MIMEText(body)
    message['to'] = recipient_email
    message['from'] = sender_email
    message['subject'] = subject

    # Encode the message
    raw = base64.urlsafe_b64encode(message.as_bytes()).decode('utf-8')
    message_body = {'raw': raw}

    # Send the email
    try:
        message = service.users().messages().send(userId='me', body=message_body).execute()
        print(f"Message sent successfully! Message Id: {message['id']}")
    except Exception as error:
        print(f"An error occurred: {error}")

if __name__ == '__main__':
    
    # Assuming 'subset_df' is the filtered DataFrame
    sender = "your_email@gmail.com"
    recipient = EMAIL_ID
    
    # Generate email body from the DataFrame
    body = format_dataframe(filtered_df)

    # Get the current date for the email subject
    current_date = datetime.datetime.now().strftime('%Y-%m-%d')
    subject = f"DSA Reminder - {current_date}"

    # Authenticate and send the email
    creds = authenticate()
    for idx, row in filtered_df.iterrows():
        title = row['Problem Title']
        url = row['URL']  # Fetch the URL from the DataFrame
        
        # Add event to calendar
        add_event_to_calendar(creds, title, url)  # Always creates for today
# Out:
# Event created: https://www.google.com/calendar/event?eid=bHRmN2JlaXVzMDRxN2N1OTYycnFqOWdmYmsgZHNhcmVtYWluZGVyQG0
# Event created: https://www.google.com/calendar/event?eid=ZXNuMmFlczRucDhyZWYzMXQ2YXRqc3VvbmMgZHNhcmVtYWluZGVyQG0
# Event created: https://www.google.com/calendar/event?eid=MzdtdXF0cDZicHRjMjRjaDU4NWZ2OTdxbXMgZHNhcmVtYWluZGVyQG0
# Event created: https://www.google.com/calendar/event?eid=aWdhYXYyczRmOW1hOHA0MG81NWpycmRobmMgZHNhcmVtYWluZGVyQG0
# Event created: https://www.google.com/calendar/event?eid=aHRvMWFqZmExZWd0N3YwaTVnOXVxOHIyNW8gZHNhcmVtYWluZGVyQG0
# Event created: https://www.google.com/calendar/event?eid=czE2dHNpdTJpN3U3aXMxNjNobTE2OWxzNTAgZHNhcmVtYWluZGVyQG0
# Event created: https://www.google.com/calendar/event?eid=bGU3Zm9rbzdpNGViYnM1cTc4MWh1Z2w5ZG8gZHNhcmVtYWluZGVyQG0
# Event created: https://www.google.com/calendar/event?eid=MWpkNWoyZWh0MGhsOGExa2hpdnJiMTBlZDAgZHNhcmVtYWluZGVyQG0
# Event created: https://www.google.com/calendar/event?eid=NnRlc3Fvcm9rN3MwOThiMXA3N2FybnVyNDQgZHNhcmVtYWluZGVyQG0
# Event created: https://www.google.com/calendar/event?eid=c2tiZjJxaTAwMzQyZG5hZXUybG11OG92a3MgZHNhcmVtYWluZGVyQG0
